# %%
# Simple Calculator

import math

class Calculator:
    def __init__(self, value, result = 0) -> None:
        self.value = value
        self.result = result

    def addition(self, operand):
        return self.handle(operand)
    
    def subtraction(self, operand):
        return self.handle(operand)
    
    def multiplication(self, operand):
        return self.handle(operand)
    
    def handle(self, operand):
        if (isinstance(self.value, list)):
            for n in self.value:
                if ('+' in operand ):
                    self.result += n
                elif ('-' in operand):
                    self.result -=n
                elif ('*' in operand):
                    self.result *= n 
            return self.result
        else:
            return print('Oops! this operation does not exist.')
    

# Enter the type of operation you want to calculate

list_of_operation = set(['*', '+', '-', '/'])

operation = set([input('Please kindly enter the type of operation you want to make: hints (*,/,-,+) : ')])

while operation.isdisjoint(list_of_operation):
    operation = set([input('Sorry this operation does not exist. \n Please kindly enter a valid the type of operation you want to make: hints (*,/,-,+) : ')])

if(operation.issubset(list_of_operation)):

    value = []

    while(True):
        
        x = (input('Enter input. \n you can end this by typing (end) : '))

        if x.isnumeric() or x == 'end':
            if x == 'end':

                break

            value.append(int(x))

        else:
            print('The value you entered is not a numeric number')
            break

    calculator = Calculator(value, result = 1)

#     print('Result : ', calculator.addition(operation))
        
#     print('Result : ', calculator.subtraction(operation))

    print('Result : ', calculator.multiplication(operation))
        
else:
    print('Sorry this operation does not exist.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 67
#      61     calculator = Calculator(value, result = 1)
#      63 #     print('Result : ', calculator.addition(operation))
#      64
#      65 #     print('Result : ', calculator.subtraction(operation))
# ---> 67     print('Result : ', calculator.multiplication(operation))
#      69 else:
#      70     print('Sorry this operation does not exist.')
#
# Cell In[121], line 17, in Calculator.multiplication(self, operand)
#      16 def multiplication(self, operand):
# ---> 17     return self.handle(operand)
#
# Cell In[121], line 20, in Calculator.handle(self, operand)
#      19 def handle(self, operand):
# ---> 20     if (isinstance(self.value, list)):
#      21         for n in self.value:
#      22             if ('+' in operand ):
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union
